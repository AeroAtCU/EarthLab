# %%
import rasterio as rio
from matplotlib import pyplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-3ada12f9e073> in <module>
#       1 import rasterio as rio
# ----> 2 from matplotlib import plt
#
# ImportError: cannot import name 'plt' from 'matplotlib' (/home/ian/anaconda3/envs/earth-analytics-python/lib/python3.7/site-packages/matplotlib/__init__.py)

# %%
dirpath = "/home/ian/Documents/EarthLab/Spring2020/data/"
filename = "20200220_165505_0f34_3B_AnalyticMS_SR.tif"
filepath = dirpath + filename

src = rio.open(filepath)
src
array = src.read(1)
array.shape
# Out:
# (4365, 8943)

# %%
pyplot.imshow(array, cmap='pink')
pyplot.figsize=(50,10) # does nothing.
pyplot.show()
